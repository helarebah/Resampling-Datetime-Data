# %% [markdown]
# <a href="https://colab.research.google.com/github/helarebah/Resampling-Datetime-Data/blob/main/Resampling_Datetime_Data(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1) Load the data and make a datetime index.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url ="https://docs.google.com/spreadsheets/d/e/2PACX-1vT_jChgNsQbHbg4TGepzIqk8XC9DTIKmyyxb1upo5cfZCgbfIUQc2ZC0YMzuU5uApP140Ob49KBjdqh/pub?gid=1198589591&single=true&output=csv"
df = pd.read_csv(url)
df
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101          2.0       7.0              52.0       2.3       -4.1
# 1      19790102          6.0       1.7              27.0       1.6       -2.6
# 2      19790103          5.0       0.0              13.0       1.3       -2.8
# 3      19790104          8.0       0.0              13.0      -0.3       -2.6
# 4      19790105          6.0       2.0              29.0       5.6       -0.8
# ...         ...          ...       ...               ...       ...        ...
# 15336  20201227          1.0       0.9              32.0       7.5        7.5
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
# ...

# %% [markdown]
# Convert the date column to datetime dtype.

# %%
pd.to_datetime(df['date'])
# Out:
# 0       1970-01-01 00:00:00.019790101
# 1       1970-01-01 00:00:00.019790102
# 2       1970-01-01 00:00:00.019790103
# 3       1970-01-01 00:00:00.019790104
# 4       1970-01-01 00:00:00.019790105
#                      ...
# 15336   1970-01-01 00:00:00.020201227
# 15337   1970-01-01 00:00:00.020201228
# 15338   1970-01-01 00:00:00.020201229
# 15339   1970-01-01 00:00:00.020201230
# 15340   1970-01-01 00:00:00.020201231
# Name: date, Length: 15341, dtype: datetime64[ns]

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
df['date']
# Out:
# 0       1979-01-01
# 1       1979-01-02
# 2       1979-01-03
# 3       1979-01-04
# 4       1979-01-05
#            ...
# 15336   2020-12-27
# 15337   2020-12-28
# 15338   2020-12-29
# 15339   2020-12-30
# 15340   2020-12-31
# Name: date, Length: 15341, dtype: datetime64[ns]

# %% [markdown]
# Set the date column as the index.

# %%
df = df.set_index('date')
df
# Out:
#             cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# date
# 1979-01-01          2.0       7.0              52.0       2.3       -4.1
# 1979-01-02          6.0       1.7              27.0       1.6       -2.6
# 1979-01-03          5.0       0.0              13.0       1.3       -2.8
# 1979-01-04          8.0       0.0              13.0      -0.3       -2.6
# 1979-01-05          6.0       2.0              29.0       5.6       -0.8
# ...                 ...       ...               ...       ...        ...
# 2020-12-27          1.0       0.9              32.0       7.5        7.5
# 2020-12-28          7.0       3.7              38.0       3.6        1.1
# 2020-12-29          7.0       0.0              21.0       4.1        2.6
# 2020-12-30          6.0       0.4              22.0       5.6        2.7
# 2020-12-31          7.0       1.3              34.0       1.5       -0.8
#
#             min_temp  precipitation  pressure  snow_depth
# date
# ...

# %%
df.index
# Out:
# DatetimeIndex(['1979-01-01', '1979-01-02', '1979-01-03', '1979-01-04',
#                '1979-01-05', '1979-01-06', '1979-01-07', '1979-01-08',
#                '1979-01-09', '1979-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='date', length=15341, freq=None)

# %%
df = df.loc['2000':, ['precipitation', 'mean_temp', 'min_temp',
                      'max_temp', 'snow_depth']]
df
# Out:
#             precipitation  mean_temp  min_temp  max_temp  snow_depth
# date
# 2000-01-01            0.0        7.0       4.9      10.8         0.0
# 2000-01-02            0.2        7.9       5.0      11.5         0.0
# 2000-01-03            6.0        9.4       7.2       9.5         0.0
# 2000-01-04            0.2        7.0       4.4      11.0         0.0
# 2000-01-05            0.8        6.4       1.9      10.8         0.0
# ...                   ...        ...       ...       ...         ...
# 2020-12-27            2.0        7.5       7.6       7.5         NaN
# 2020-12-28            0.2        1.1      -1.3       3.6         NaN
# 2020-12-29            0.0        2.6       1.1       4.1         NaN
# 2020-12-30            0.0        2.7      -0.1       5.6         NaN
# 2020-12-31            0.0       -0.8      -3.1       1.5         NaN
#
# [7671 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# precipitation     390
# mean_temp         419
# min_temp          386
# max_temp          390
# snow_depth       1752
# dtype: int64

# %%
df['mean_temp'] = df['mean_temp'].interpolate()
df['max_temp'] = df['max_temp'].interpolate()
df['min_temp'] = df['min_temp'].interpolate()

# %%
df.isna().sum()
# Out:
# precipitation     390
# mean_temp           0
# min_temp            0
# max_temp            0
# snow_depth       1752
# dtype: int64

# %%
df['precipitation'] = df['precipitation'].fillna(0)
df['snow_depth'] = df['snow_depth'].fillna(0)

# %%
df.isna().sum()
# Out:
# precipitation    0
# mean_temp        0
# min_temp         0
# max_temp         0
# snow_depth       0
# dtype: int64

# %% [markdown]
# # Part 2) Answer the Questions with Visualizations (Using the Correct Frequency)

# %% [markdown]
# For each of the following questions, make a new copy of the dataframe resampled to the correct frequency for the question.

# %% [markdown]
# Plot the feature that the question is asking about.
# If there is a specific time period, plot only that time period.

# %% [markdown]
# Q1: What month had the most precipitation between 2000 through 2010?

# %%
pre_MS_res = df.resample("MS").mean()
pre_MS_res.name = 'Resampled'
pre_MS_res.head()
# Out:
#             precipitation  mean_temp  min_temp   max_temp  snow_depth
# date
# 2000-01-01       0.461290   5.614516  2.648387   8.482258         0.0
# 2000-02-01       2.144828   7.181034  3.903448  10.293103         0.0
# 2000-03-01       0.432258   8.491935  4.891935  12.175806         0.0
# 2000-04-01       2.393333   8.996667  5.275000  13.161667         0.0
# 2000-05-01       2.206452  13.798387  9.529032  17.945161         0.0

# %% [markdown]
# Find the date and corresponding value for the max precipitation.

# %%
max_date = df['precipitation'].idxmax()
max_date
# Out:
# Timestamp('2015-08-26 00:00:00')

# %%
ts = df['precipitation'].copy()
ts
# Out:
# date
# 2000-01-01    0.0
# 2000-01-02    0.2
# 2000-01-03    6.0
# 2000-01-04    0.2
# 2000-01-05    0.8
#              ...
# 2020-12-27    2.0
# 2020-12-28    0.2
# 2020-12-29    0.0
# 2020-12-30    0.0
# 2020-12-31    0.0
# Name: precipitation, Length: 7671, dtype: float64

# %%
import matplotlib.ticker as mticks
import matplotlib.dates as mdates

# %% [markdown]
# Plot the feature and time period that corresponds to the question.
# Make sure to meet the "Visualization Requirements" below!
# Determine the date and value for the most precipitation (the max precipitation).
# Add a vertical line at this date with a label that says the date (using date format: "April 2000") and the max precipitation value.
# Make sure to add a legend so that your label is visible.

# %% [markdown]
# Q1 Visualization Requirements
#
# Use a combination of pandas, matplotlib tick formatters, tick locators, and the fig.autofmt_xdate method to:
#
# Create a wide figure (e.g. figsize=(12,3))
#
# With the title "Precipitation for 2000-2010"
#
# With a ylabel of "Inches"
#
# Customize the major xaxis ticks to:
#
# Have major xaxis ticks every 1 year.
#
# Use 4-digit years for the labels
#
# Rotate the major ticks' labels 90 degrees.
#
# Customize the minor xaxis ticks to:
#
# Have minor xaxis ticks every 3 months
#
# Do not label the minor ticks.

# %%
ax = ts.plot(marker='.',lw=1);
fig = ax.get_figure()
fig.autofmt_xdate()
ax.axvline(x=ts.idxmax(), color='r', linestyle='--', label=f'Max Precipitation: {max_date}, {max_date}')
plt.xticks(rotation=45, ha='right')
ax.legend()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%B %Y'))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,3))
df.plot(ax=ax)
# Out:
# <Axes: xlabel='date'>

# %%
fig, ax = plt.subplots(figsize=(12,3))
ax.plot(df.index, df['precipitation'], color='b')

# Title and labels
ax.set_title('Precipitation for 2000-2010')
ax.set_ylabel('Inches')

# Customize major xaxis ticks
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=90)

# Customize minor xaxis ticks
ax.xaxis.set_minor_locator(mdates.MonthLocator(interval=3))

plt.tight_layout()
plt.show()

# %% [markdown]
# Q2: Which year between 2000-2020 had the coolest average temperature?
# Resample the  mean_temp data to a Yearly frequency using .mean() as the aggregation method.
#
# Plot the feature and time period that corresponds to the question.
#
# Make sure to meet the "Visualization Requirements" below!
#
# Determine the year and value for the lowest mean temp.
#
# Add a vertical line at this date with a label that says the date (using date format: "2000") and the lowest mean temperature value.

# %% [markdown]
# Q2 Visualization Requirements
#
# Use a combination of pandas, matplotlib tick formatters, tick locators, and the fig.autofmt_xdate method to:
#
# Create a wide figure (e.g. figsize=(12,3))
# With the title "Average Temperature"
#
# With a ylabel of "Degrees"
#
# Customize the major xaxis ticks to:
#
# Have major xaxis ticks every 5 years.
#
# Use 4-digit years for the labels
#
# Rotate the major ticks' labels 90 degrees.
#
# Customize the minor xaxis ticks to:
#
# Have minor xaxis ticks every 1 year
#
# Do not label the minor ticks.

# %%
dates = pd.date_range(start='2000-01-01', end='2020-12-31', freq='D')
yearly_mean_temp = df.resample('Y').mean()
coolest_temp = yearly_mean_temp.min()[0]
coolest_temp
# Out:
# 1.155068493150685

# %%
coolest_year = yearly_mean_temp.idxmin()[0]
coolest_year
# Out:
# Timestamp('2005-12-31 00:00:00')

# %%
fig, ax = plt.subplots(figsize=(12, 1))
ax.plot(yearly_mean_temp.index, yearly_mean_temp['mean_temp'], marker='o', color='b')

# Add vertical line at the date with the lowest mean temperature
ax.axvline(x=coolest_year, color='r', linestyle='--', label=f'Lowest Temp: {coolest_year.year}')
ax.text(coolest_year, coolest_temp, f'{coolest_year.year}: {coolest_temp:.2f}°C', rotation=90)

# Title and labels
ax.set_title('Average Temperature')
ax.set_ylabel('Degrees')

# Customize major xaxis ticks
ax.xaxis.set_major_locator(mdates.YearLocator(5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=90)

# Customize minor xaxis ticks
ax.xaxis.set_minor_locator(mdates.YearLocator(1))

plt.tight_layout()
plt.show() ;
# Out:
# <ipython-input-47-e507be634269>:20: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
